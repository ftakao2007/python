# %% [markdown]
# # リフレクションプログラミング
#
# * プログラミング実行中に、そのプログラムの情報を取得したり操作したりすること

# %%
## オブジェクトのインスタンス変数調査
class Foo
  def initialize
    @foo = 1
    @bar = 2
    @baz = 3
  end

  def sample_method
  end
end

object1 = Foo.new

### オブジェクトを出力
p object1      ### 出力例) #<Foo:0x007ffda391d8b0 @foo=1, @bar=2, @baz=3>

### 配列の要素としてインスタンス変数名をシンボルで返す
p object1.instance_variables       ### 出力例) [:@foo, :@bar, :@baz]

### オブジェクトに対してインスタンス変数名が定義されているか直接問い合わせる
p object1.instance_variable_defined?(:@bar)      ### 出力例) true or false

### インスタンス変数を参照
p object1.instance_variable_get(:@bar)     ### (インスタンス変数の値が出力される)

### 要素を取り出す
object1.instance_variables.select do |v|
  p v
end
### 出力例) :@foo
###        :@bar
###        :@baz

### 各要素にあるインスタンス変数の値を取り出す
object1.instance_variables.select do |v|
  p object1.instance_variable_get(v)
end
### 出力例) 1
###        2
###        3

### インスタンス変数の値を更新する
object1.instance_variable_set(:@bar, 4)
p object1.instance_variable_get(:@bar)      ### 出力例) 4

### インスタンス変数の値を更新する
object1.instance_variable_set(:@qux, 5)
p object1
p object1.instance_variable_get(:@qux)
### 出力例) #<Foo:0x007f970996f008 @foo=1, @bar=2, @baz=3, @qux=5>
###        5
# Out:
# #<Foo:0x007ffda4027430 @foo=1, @bar=2, @baz=3>
# [:@foo, :@bar, :@baz]
# true
# 2
# :@foo
# :@bar
# :@baz
# 1
# 2
# 3
# 4
# #<Foo:0x007ffda4027430 @foo=1, @bar=4, @baz=3, @qux=5>
# 5
# 5

# %% [markdown]
# # オブジェクトが持つメソッドの確認

# %%
# オブジェクトが持つメソッドの確認
class ParentClass
  def super_public_method
    'super_public_method'
  end

  private

  def super_private_method
    'super_private_method'
  end

  protected

  def super_protected_method
    'super_protected_method'
  end
end

class ChildClass < ParentClass

  def public_method
  end

  private

  def private_method
  end

  protected

  def protected_method
  end
end

child = ChildClass.new

def child.singleton_method
end

p "メソッドの一覧表示"
child.methods.each do |v|
  p v
end

p "====================="
p "publicメソッドの表示"
child.public_methods.each do |v|
  p v
end

p "====================="
p "privateメソッドの表示"
child.private_methods.each do |v|
  p v
end

p "====================="
p "protectedメソッドの表示"
child.protected_methods.each do |v|
  p v
end

p "====================="
p "singletonメソッドの表示"
child.singleton_methods.each do |v|
  p v
end

p "====================="
p "引数にfalseを渡すとsingletonメソッドのみ表示"
p child.methods(false)

# (以下今の段階では飛ばし)

# オブジェクトにメソッドが定義されているかを確認する

# has_method = ParentClass.new
# ### super_public_methodがあるのでtrue
# p has_method.respond_to?(:super_public_method)
#
# ### privateのメソッドはデフォルトではfalse
# p has_method.respond_to?(:super_private_method)
#
# ### 第二引数をtrueにするとprivate_methodも確認できるようになる
# p has_method.respond_to?(:super_private_method, true)

# (以下今の段階では飛ばし)

# Object#sendで任意のメソッドを呼び出す

### protectedやprivateメソッドも呼び出せる
# send_method = ParentClass.new
# p send_method.send(:super_public_method)
# p send_method.send(:super_protected_method)
# p send_method.send(:super_private_method)

### ライブラリを作るときはライブラリ使用者側でsendがオーバーライドされている可能性を考慮して__send__を使う
# p send_method.__send__(:super_public_method)

# ----------------------- #
# クラスについて調べる
# Out:
# "メソッドの一覧表示"
# :singleton_method
# :public_method
# :protected_method
# :super_public_method
# :super_protected_method
# :pry
# :__binding__
# :pretty_print
# :pretty_print_cycle
# :pretty_print_instance_variables
# :pretty_print_inspect
# :to_json
# :instance_of?
# :public_send
# :instance_variable_get
# :instance_variable_set
# :instance_variable_defined?
# :remove_instance_variable
# :private_methods
# :kind_of?
# :instance_variables
# :tap
# :define_singleton_method
# :is_a?
# :extend
# :to_enum
# :enum_for
# :<=>
# :pretty_inspect
# :===
# :=~
# :!~
# :eql?
# :respond_to?
# :freeze
# :inspect
# :display
# :object_id
# :send
# :gem
# :to_s
# :method
# :nil?
# :hash
# :class
# :singleton_class
# :clone
# :dup
# :itself
# :taint
# :tainted?
# :untaint
# :untrust
# :trust
# :untrusted?
# :methods
# :protected_methods
# :frozen?
# :public_methods
# :singleton_methods
# :!
# :==
# :!=
# :__send__
# :equal?
# :instance_eval
# :instance_exec
# :__id__
# "====================="
# "publicメソッドの表示"
# :singleton_method
# :public_method
# :super_public_method
# :pry
# :__binding__
# :pretty_print
# :pretty_print_cycle
# :pretty_print_instance_variables
# :pretty_print_inspect
# :to_json
# :instance_of?
# :public_send
# :instance_variable_get
# :instance_variable_set
# :instance_variable_defined?
# :remove_instance_variable
# :private_methods
# :kind_of?
# :instance_variables
# :tap
# :define_singleton_method
# :is_a?
# :extend
# :to_enum
# :enum_for
# :<=>
# :pretty_inspect
# :===
# :=~
# :!~
# :eql?
# :respond_to?
# :freeze
# :inspect
# :display
# :object_id
# :send
# :gem
# :to_s
# :method
# :nil?
# :hash
# :class
# :singleton_class
# :clone
# :dup
# :itself
# :taint
# :tainted?
# :untaint
# :untrust
# :trust
# :untrusted?
# :methods
# :protected_methods
# :frozen?
# :public_methods
# :singleton_methods
# :!
# :==
# :!=
# :__send__
# :equal?
# :instance_eval
# :instance_exec
# :__id__
# "====================="
# "privateメソッドの表示"
# :private_method
# :super_private_method
# :timeout
# :Digest
# :DelegateClass
# :sprintf
# :format
# :Integer
# :Float
# :String
# :Array
# :Hash
# :catch
# :throw
# :loop
# :block_given?
# :Rational
# :Complex
# :trace_var
# :untrace_var
# :JSON
# :at_exit
# :jj
# :set_trace_func
# :caller
# :caller_locations
# :select
# :test
# :fork
# :exit
# :`
# :gem_original_require
# :j
# :sleep
# :pp
# :URI
# :respond_to_missing?
# :load
# :exec
# :exit!
# :system
# :spawn
# :abort
# :open
# :syscall
# :print
# :printf
# :puts
# :putc
# :readlines
# :Pathname
# :p
# :readline
# :gets
# :srand
# :rand
# :proc
# :lambda
# :initialize_copy
# :initialize_clone
# :initialize_dup
# :trap
# :require
# :require_relative
# :autoload
# :autoload?
# :binding
# :local_variables
# :warn
# :raise
# :fail
# :global_variables
# :__method__
# :__callee__
# :__dir__
# :eval
# :iterator?
# :method_missing
# :singleton_method_added
# :singleton_method_removed
# :singleton_method_undefined
# :initialize
# "====================="
# "protectedメソッドの表示"
# :protected_method
# :super_protected_method
# "====================="
# "singletonメソッドの表示"
# :singleton_method
# "====================="
# "引数にfalseを渡すとsingletonメソッドのみ表示"
# [:singleton_method]
# [:singleton_method]

# %%
module FooModule
  MODULE_CONST_VAR = 1
end

class FooClassValiables

  include FooModule
  CLASS_CONST_VAR = 2
  @@class_val = "fooclassval"

  class InnerFooClassValiables
    INNER_CLASS_CONST_VAR = 3
  end

  def def_lazy_class_val
    @@lazy_class_val = "foolazyclassval"
  end
end

### 呼び出し時点で定義されているクラス変数の一覧を表示
p FooClassValiables.class_variables

### lazy_class_valを定義して呼び出し
FooClassValiables.new.def_lazy_class_val
p FooClassValiables.class_variables

### クラス変数が定義されているか直接問い合わせる
p FooClassValiables.class_variable_defined?('@@class_val')

### クラス変数の値を取得
p FooClassValiables.class_variable_get('@@class_val')

### クラス変数に値を設定
FooClassValiables.class_variable_set('@@class_val', 'hoge')
p FooClassValiables.class_variable_get('@@class_val')

### 定数の一覧取得
p FooClassValiables.constants

# 第二引数をfalseにすると継承したクラスやincludeしたモジュールの定数は表示されない
p FooClassValiables.constants(false)

# innerクラスの定数のみ表示
p FooClassValiables::InnerFooClassValiables.constants
# Out:
# (pry):1626: warning: already initialized constant FooModule::MODULE_CONST_VAR
# (pry):1582: warning: previous definition of MODULE_CONST_VAR was here
# (pry):1632: warning: already initialized constant FooClassValiables::CLASS_CONST_VAR
# (pry):1588: warning: previous definition of CLASS_CONST_VAR was here
# (pry):1636: warning: already initialized constant FooClassValiables::InnerFooClassValiables::INNER_CLASS_CONST_VAR
# (pry):1592: warning: previous definition of INNER_CLASS_CONST_VAR was here
# [:@@class_val, :@@lazy_class_val]
# [:@@class_val, :@@lazy_class_val]
# true
# "fooclassval"
# "hoge"
# [:CLASS_CONST_VAR, :InnerFooClassValiables, :MODULE_CONST_VAR]
# [:CLASS_CONST_VAR, :InnerFooClassValiables]
# [:INNER_CLASS_CONST_VAR]
# [:INNER_CLASS_CONST_VAR]

# %% [markdown]
# # OurOpenData
#
# http://ouropendata.jp/

# %%
import pandas as pd
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
#from matplotlib.pyplot as plt import *

csv_url = 'https://www.mizuhobank.co.jp/rate/market/csv/quote.csv'
df = pd.read_csv(csv_url, skiprows=2, index_col=0, parse_dates=True)
plt.plot(df[['USD', 'GBP', 'EUR']])
plt.plot(df[['USD', 'GBP', 'EUR']].rolling(window=250).mean())
#plot.show()

# %%
csv_url = 'https://www.mizuhobank.co.jp/rate/market/csv/quote.csv'
df = pd.read_csv(csv_url, skiprows=2, index_col=0, parse_dates=True)
df_pri = df [['USD', 'GBP', 'EUR']]
df_pri['2016':'2017'].plot()

# %%
csv_url = 'http://ouropendata.jp/dataset/1238/resource/3831/H29-05-01.csv'
#df = pd.read_csv(csv_url, skiprows=4, index_col=0, parse_dates=True,encoding="SHIFT-JIS")
df = pd.read_csv(csv_url, skiprows=4, index_col=0, parse_dates=True,encoding="utf-8")
df.head(3)
#df_pri = df [['USD', 'GBP', 'EUR']]
#df_pri.head(3)

#df = pd.read_csv(csv_url)
#df.head(3)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-39-7dc81cf59412> in <module>()
#       1 csv_url = 'http://ouropendata.jp/dataset/1238/resource/3831/H29-05-01.csv'
#       2 #df = pd.read_csv(csv_url, skiprows=4, index_col=0, parse_dates=True,encoding="SHIFT-JIS")
# ----> 3 df = pd.read_csv(csv_url, skiprows=4, index_col=0, parse_dates=True,encoding="utf-8")
#       4 df.head(3)
#       5 #df_pri = df [['USD', 'GBP', 'EUR']]
#
# ...

# %%
# ファイルの中身確認
f = open("csv/hoge.csv", "r")
for line in f:
    print(line, end="")
# Out:
# 10,8,3
# 12,1,5
# 5,3,3

# %%
import pandas as pd
csv_url = 'csv/hoge.csv'
df = pd.read_csv(csv_url)
df
#df = pd.read_csv(csv_url, skiprows=4, index_col=0, parse_dates=True,encoding="SHIFT-JIS")
#df = pd.read_csv(csv_url, skiprows=4, index_col=0, parse_dates=True,encoding="utf-8")
# Out:
#    10  8  3
# 0  12  1  5
# 1   5  3  3

# %%
# ファイルの中身確認
f = open("csv/fuga.csv", "r", encoding="UTF-8")
for line in f:
    print(line, end="")
# Out:
# 名前, 年齢, 職業
# 太郎, 31, ITエンジニア
# 次郎, 27, 教師
# 三郎, 25, 宮大工

# %%
import pandas as pd
csv_url = 'csv/fuga.csv'
df = pd.read_csv(csv_url)
df
# Out:
#    名前   年齢        職業
# 0  太郎   31   ITエンジニア
# 1  次郎   27        教師
# 2  三郎   25       宮大工

# %%
import pandas as pd
csv_url = 'csv/H29-05-01.csv'
df = pd.read_csv(csv_url, encoding="SHIFT-JIS")
df
# Out:
#    Unnamed: 0                                            H29.5.1 Unnamed: 2  \
# 0         NaN                                                NaN        NaN
# 1         NaN                                         推　　計　　人　　口        NaN
# 2         NaN                                                NaN        NaN
# 3         NaN                                                総　数          男
# 4          県計                                            745,178    355,009
# 5         徳島市                                            257,635    122,606
# 6         鳴門市                                             57,953     27,576
# 7        小松島市                                             37,913     18,343
# 8         阿南市                                             71,806     34,713
# 9        吉野川市                                             40,519     19,011
# 10        阿波市                                             36,349     17,224
# ...

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

### 推計人口
csv_url = 'csv/H29-05-01.csv'
df = pd.read_csv(csv_url, skiprows=4, index_col=0, encoding="SHIFT-JIS")
df.loc[:,['総　数','男','女']][1:25]

df2 = pd.read_csv(csv_url, skiprows=4, index_col=0, encoding="SHIFT-JIS")
df2.loc[:,['男','女']][1:25]

#df2.plot.bar(y=['男', '女'], alpha=0.6, figsize=(12,3), stacked=True, cmap='Blues')
#plt.title(u'徳島県推計人口', size=16)
# Out:
#              男        女
# 徳島市    122,606  135,029
# 鳴門市     27,576   30,377
# 小松島市    18,343   19,570
# 阿南市     34,713   37,093
# 吉野川市    19,011   21,508
# 阿波市     17,224   19,125
# 美馬市     14,060   15,618
# 三好市     12,014   13,770
# 勝浦町      2,475    2,711
# 上勝町        698      741
# 佐那河内村    1,068    1,147
# 石井町     11,955   13,417
# 神山町      2,365    2,651
# 那賀町      3,784    4,216
# 牟岐町      1,896    2,204
# 美波町      3,148    3,632
# 海陽町      4,224    4,790
# 松茂町      7,472    7,560
# 北島町     10,896   11,680
# 藍住町     16,659   18,148
# 板野町      6,388    6,936
# 上板町      5,640    6,209
# つるぎ町     3,962    4,493
# 東みよし町    6,832    7,544

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

df2 = pd.DataFrame(rand(10, 4), columns=['a', 'b', 'c', 'd'])
df2.plot(kind='bar');
plt.show()
# Out:
# -------------------------------------------------------------------
# NameError                         Traceback (most recent call last)
# <ipython-input-39-f5a7b878cf16> in <module>()
#       3 import matplotlib.pyplot as plt
#       4
# ----> 5 df2 = pd.DataFrame(rand(10, 4), columns=['a', 'b', 'c', 'd'])
#       6 df2.plot(kind='bar');
#       7 plt.show()
#
# NameError: name 'rand' is not defined

# %%
url = 'cvs/ambientNOxCH.csv'
df_sample = pd.read_csv(url, parse_dates=1, index_col=1)

# dfの準備
df = df_sample.iloc[:, 1:]

# df_monthlyの準備
df_monthly = df.copy()
df_monthly.index = df_monthly.index.map(lambda x: x.month)
df_monthly = df_monthly.groupby(level=0).sum()
# Out:
# -------------------------------------------------------------------
# TypeError                         Traceback (most recent call last)
# <ipython-input-40-cf78da40061b> in <module>()
#       1 url = 'cvs/ambientNOxCH.csv'
# ----> 2 df_sample = pd.read_csv(url, parse_dates=1, index_col=1)
#       3
#       4 # dfの準備
#       5 df = df_sample.iloc[:, 1:]
#
# ...
